# %%
InverseNumber=LibraryFunctionLoad["/home/yangyongkang/文档/C-CPP_WolframLibrary_Example/Inversions.so","InverseNumber",{{Integer,1}},"UTF8String"]

# %%
NaiveInverseNumber=LibraryFunctionLoad["/home/yangyongkang/文档/C-CPP_WolframLibrary_Example/Naive_InverseNumber.so","Naive_InverseNumber",{{Integer,1}},Integer]
# Out:
# LibraryFunction[<>, Naive_InverseNumber, {{Integer, 1}}, Integer]

# %%
time1=(RepeatedTiming[NaiveInverseNumber[RandomSample@Range[10*#,1,-1]];]&/@Range@50)[[All,1]];

# %%
time2=(RepeatedTiming[InverseNumber[RandomSample@Range[10*#,1,-1]];]&/@Range@50)[[All,1]];

# %%
ListLinePlot[{time1,time2},PlotLegends->{"Naive","Merge"}]
# Out:
#                                                             1
# Legended[-Graphics-, Placed[LineLegend[{Directive[PointSize[--],
#                                                             72
#
# >       RGBColor[0.368417, 0.506779, 0.709798], AbsoluteThickness[1.6]],
#
#                            1
# >      Directive[PointSize[--], RGBColor[0.880722, 0.611041, 0.142051],
#                            72
#
# >       AbsoluteThickness[1.6]]}, {Naive, Merge},
#
# >     LegendMarkers -> {{False, Automatic}, {False, Automatic}}, Joined -> {True, True},
#
# >     LabelStyle -> {}, LegendLayout -> Column], After, Identity]]

# %%
Do[Table[InverseNumber@i,{i,Permutations[Range@2,{2}]}],100000]//AbsoluteTiming
# Out:
# {0.434453, Null}

# %%
Do[Table[NaiveInverseNumber@i,{i,Permutations[Range@2,{2}]}],100000];//AbsoluteTiming
# Out:
# {0.364133, Null}

# %%
1
